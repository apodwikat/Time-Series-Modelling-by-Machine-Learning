# %% [markdown]
# # Cell 1 - Title and Description
#
# # Seasonal LSTM Models for Wind Speed Forecasting
# ## Four Independent Models for Spring, Summer, Autumn, and Winter
#
# # This notebook implements separate LSTM models for each season to forecast wind speeds.
# ## Dataset: Hourly wind speeds from 2001-2002
# ## Goal: Forecast each season of 2003

# %% [markdown]
# # Import Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# Deep Learning
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# Preprocessing and Evaluation
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Cell 3 - Load and Prepare Data """# Load and Process Initial Data"""

# %%
# Load data
df = pd.read_csv(r"C:\Users\hp\Cyprus_Researh\wind2001_2002.csv")
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df.set_index('Timestamp', inplace=True)

# Add time features
df['year'] = df.index.year
df['month'] = df.index.month
df['hour'] = df.index.hour
df['day'] = df.index.day

# Define seasons
def get_season(month):
    if month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Autumn'
    else:  # months 12, 1, 2
        return 'Winter'

df['season'] = df['month'].apply(get_season)

# Add these features to your data preparation
df['hour_sin'] = np.sin(2 * np.pi * df.index.hour / 24)
df['hour_cos'] = np.cos(2 * np.pi * df.index.hour / 24)
df['day_sin'] = np.sin(2 * np.pi * df.index.day / 31)
df['day_cos'] = np.cos(2 * np.pi * df.index.day / 31)

df = df.drop(columns=["d1", "d2", "d3"])

df
# Out:
#                      Wind (m/s 10 m)  year  month  hour  day  season  \
# Timestamp
# 2001-01-01 00:00:00             9.86  2001      1     0    1  Winter
# 2001-01-01 01:00:00             8.59  2001      1     1    1  Winter
# 2001-01-01 02:00:00             9.93  2001      1     2    1  Winter
# 2001-01-01 03:00:00            11.29  2001      1     3    1  Winter
# 2001-01-01 04:00:00            10.79  2001      1     4    1  Winter
# ...                              ...   ...    ...   ...  ...     ...
# 2002-12-31 19:00:00             5.01  2002     12    19   31  Winter
# 2002-12-31 20:00:00             7.28  2002     12    20   31  Winter
# 2002-12-31 21:00:00             8.16  2002     12    21   31  Winter
# 2002-12-31 22:00:00            10.07  2002     12    22   31  Winter
# 2002-12-31 23:00:00            10.70  2002     12    23   31  Winter
#
#                      hour_sin  hour_cos       day_sin  day_cos
# Timestamp
# 2001-01-01 00:00:00  0.000000  1.000000  2.012985e-01  0.97953
# 2001-01-01 01:00:00  0.258819  0.965926  2.012985e-01  0.97953
# 2001-01-01 02:00:00  0.500000  0.866025  2.012985e-01  0.97953
# 2001-01-01 03:00:00  0.707107  0.707107  2.012985e-01  0.97953
# 2001-01-01 04:00:00  0.866025  0.500000  2.012985e-01  0.97953
# ...                       ...       ...           ...      ...
# 2002-12-31 19:00:00 -0.965926  0.258819 -2.449294e-16  1.00000
# 2002-12-31 20:00:00 -0.866025  0.500000 -2.449294e-16  1.00000
# 2002-12-31 21:00:00 -0.707107  0.707107 -2.449294e-16  1.00000
# 2002-12-31 22:00:00 -0.500000  0.866025 -2.449294e-16  1.00000
# 2002-12-31 23:00:00 -0.258819  0.965926 -2.449294e-16  1.00000
#
# [17520 rows x 10 columns]

# %% [markdown]
# # Cell 4 - Split Data by Season """# Create Seasonal Datasets"""

# %%
# Create separate dataframes for each season
seasonal_dfs = {}
for season in ['Spring', 'Summer', 'Autumn', 'Winter']:
    seasonal_dfs[season] = df[df['season'] == season].copy()
    print(f"{season} shape: {seasonal_dfs[season].shape}")
    print(f"Date range: {seasonal_dfs[season].index.min()} to {seasonal_dfs[season].index.max()}\n")
# Out:
# Spring shape: (4416, 10)
# Date range: 2001-03-01 00:00:00 to 2002-05-31 23:00:00
#
# Summer shape: (4416, 10)
# Date range: 2001-06-01 00:00:00 to 2002-08-31 23:00:00
#
# Autumn shape: (4368, 10)
# Date range: 2001-09-01 00:00:00 to 2002-11-30 23:00:00
#
# Winter shape: (4320, 10)
# Date range: 2001-01-01 00:00:00 to 2002-12-31 23:00:00

# %% [markdown]
# # Cell 5 - Prepare Sequences Function """# Define Data Preparation Functions"""

# %%
def create_sequences(data, seq_length=24):
    """Create sequences for LSTM input"""
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length)])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

def prepare_seasonal_data(season_df, seq_length=24):
    """Prepare data for one season"""
    # Normalize data
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(season_df[['Wind (m/s 10 m)']])
    
    # Split by year
    data_2001 = scaled_data[season_df.index.year == 2001]
    data_2002 = scaled_data[season_df.index.year == 2002]
    
    # Create sequences
    X_train, y_train = create_sequences(data_2001, seq_length)
    X_val, y_val = create_sequences(data_2002, seq_length)
    
    return X_train, y_train, X_val, y_val, scaler

# %% [markdown]
# # Cell 6 - Build LSTM Model Function """# Define Model Building Function"""

# %%
def build_seasonal_lstm(seq_length=24, features=1):
    model = Sequential([
        LSTM(128, input_shape=(seq_length, features), return_sequences=True),
        BatchNormalization(),
        Dropout(0.3),  # Increased dropout
        
        LSTM(64, return_sequences=True),  # Added middle layer
        BatchNormalization(),
        Dropout(0.3),
        
        LSTM(32, return_sequences=False),
        BatchNormalization(),
        Dropout(0.3),
        
        Dense(32, activation='relu'),  # Wider dense layer
        Dense(16, activation='relu'),  # Added another dense layer
        Dense(1)
    ])
    
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='mse',
        metrics=['mae']
    )
    
    return model

# %% [markdown]
# # Cell 7 - Train Models """# Train Seasonal Models"""

# %%
models = {}
histories = {}
scalers = {}

for season in ['Spring', 'Summer', 'Autumn', 'Winter']:
    print(f"\nTraining {season} model...")
    
    # Prepare data
    X_train, y_train, X_val, y_val, scaler = prepare_seasonal_data(
        seasonal_dfs[season]
    )
    scalers[season] = scaler
    
    # Build and train model
    model = build_seasonal_lstm()
    
    # Callbacks
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )
    
    checkpoint = ModelCheckpoint(
        f'c:/Users/hp/Cyprus_Researh/best_model_{season.lower()}.keras',
        monitor='val_loss',
        save_best_only=True
    )
    
    # Train
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=100,
        batch_size=32,
        callbacks=[early_stopping, checkpoint],
        verbose=1
    )
    
    models[season] = model
    histories[season] = history
# Out:
# Training Spring model...
# Epoch 1/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 11s
100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0101 - mae: 0.0783 - val_loss: 0.0068 - val_mae: 0.0650
# Epoch 31/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0092 - mae: 0.0749 - val_loss: 0.0063 - val_mae: 0.0613
# Epoch 32/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0093 - mae: 0.0740 - val_loss: 0.0053 - val_mae: 0.0561
# Epoch 33/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0095 - mae: 0.0765 - val_loss: 0.0058 - val_mae: 0.0590
# Epoch 34/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0089 - mae: 0.0740 - val_loss: 0.0058 - val_mae: 0.0589
# Epoch 35/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0079 - mae: 0.0693 - val_loss: 0.0057 - val_mae: 0.0590
# Epoch 36/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0085 - mae: 0.0713 - val_loss: 0.0056 - val_mae: 0.0568
# Epoch 37/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0099 - mae: 0.0769 - val_loss: 0.0070 - val_mae: 0.0651
# Epoch 38/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0087 - mae: 0.0730 - val_loss: 0.0057 - val_mae: 0.0592
# Epoch 39/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0081 - mae: 0.0715 - val_loss: 0.0055 - val_mae: 0.0574
# Epoch 40/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0084 - mae: 0.0717 - val_loss: 0.0053 - val_mae: 0.0564
# Epoch 41/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0082 - mae: 0.0703 - val_loss: 0.0052 - val_mae: 0.0552
# Epoch 42/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0096 - mae: 0.0754 - val_loss: 0.0096 - val_mae: 0.0794
# Epoch 43/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0087 - mae: 0.0725 - val_loss: 0.0060 - val_mae: 0.0605
# Epoch 44/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0081 - mae: 0.0704 - val_loss: 0.0054 - val_mae: 0.0572
# Epoch 45/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0086 - mae: 0.0706 - val_loss: 0.0057 - val_mae: 0.0574
# Epoch 46/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0089 - mae: 0.0724 - val_loss: 0.0055 - val_mae: 0.0569
# Epoch 47/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0081 - mae: 0.0690 - val_loss: 0.0063 - val_mae: 0.0599
# Epoch 48/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0083 - mae: 0.0696 - val_loss: 0.0054 - val_mae: 0.0555
# Epoch 49/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0081 - mae: 0.0699 - val_loss: 0.0053 - val_mae: 0.0561
# Epoch 50/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0082 - mae: 0.0710 - val_loss: 0.0062 - val_mae: 0.0603
# Epoch 51/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0088 - mae: 0.0718 - val_loss: 0.0058 - val_mae: 0.0584
#
# Training Summer model...
# Epoch 1/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 11s 50ms/step - loss: 0.1058 - mae: 0.2524 - val_loss: 0.1483 - val_mae: 0.3376
# Epoch 2/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0411 - mae: 0.1601 - val_loss: 0.1148 - val_mae: 0.2886
# Epoch 3/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0306 - mae: 0.1374 - val_loss: 0.0868 - val_mae: 0.2480
# Epoch 4/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0238 - mae: 0.1238 - val_loss: 0.0400 - val_mae: 0.1675
# Epoch 5/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0208 - mae: 0.1145 - val_loss: 0.0292 - val_mae: 0.1428
# Epoch 6/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0188 - mae: 0.1080 - val_loss: 0.0200 - val_mae: 0.1155
# Epoch 7/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0180 - mae: 0.1071 - val_loss: 0.0150 - val_mae: 0.0989
# Epoch 8/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0152 - mae: 0.0968 - val_loss: 0.0124 - val_mae: 0.0900
# Epoch 9/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0149 - mae: 0.0966 - val_loss: 0.0156 - val_mae: 0.1032
# Epoch 10/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0136 - mae: 0.0918 - val_loss: 0.0133 - val_mae: 0.0932
# Epoch 11/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0128 - mae: 0.0904 - val_loss: 0.0088 - val_mae: 0.0753
# Epoch 12/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0134 - mae: 0.0905 - val_loss: 0.0082 - val_mae: 0.0709
# Epoch 13/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0127 - mae: 0.0887 - val_loss: 0.0065 - val_mae: 0.0633
# Epoch 14/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0120 - mae: 0.0868 - val_loss: 0.0056 - val_mae: 0.0582
# Epoch 15/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0124 - mae: 0.0865 - val_loss: 0.0062 - val_mae: 0.0613
# Epoch 16/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0111 - mae: 0.0829 - val_loss: 0.0073 - val_mae: 0.0685
# Epoch 17/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0099 - mae: 0.0785 - val_loss: 0.0128 - val_mae: 0.0913
# Epoch 18/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0103 - mae: 0.0800 - val_loss: 0.0120 - val_mae: 0.0899
# Epoch 19/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0109 - mae: 0.0829 - val_loss: 0.0073 - val_mae: 0.0693
# Epoch 20/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0102 - mae: 0.0785 - val_loss: 0.0070 - val_mae: 0.0667
# Epoch 21/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0087 - mae: 0.0738 - val_loss: 0.0063 - val_mae: 0.0628
# Epoch 22/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0085 - mae: 0.0717 - val_loss: 0.0058 - val_mae: 0.0598
# Epoch 23/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0091 - mae: 0.0752 - val_loss: 0.0064 - val_mae: 0.0626
# Epoch 24/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0099 - mae: 0.0787 - val_loss: 0.0052 - val_mae: 0.0562
# Epoch 25/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0093 - mae: 0.0758 - val_loss: 0.0055 - val_mae: 0.0578
# Epoch 26/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0092 - mae: 0.0762 - val_loss: 0.0082 - val_mae: 0.0740
# Epoch 27/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0078 - mae: 0.0693 - val_loss: 0.0060 - val_mae: 0.0619
# Epoch 28/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0087 - mae: 0.0727 - val_loss: 0.0062 - val_mae: 0.0610
# Epoch 29/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0097 - mae: 0.0775 - val_loss: 0.0062 - val_mae: 0.0621
# Epoch 30/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0079 - mae: 0.0699 - val_loss: 0.0054 - val_mae: 0.0579
# Epoch 31/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0080 - mae: 0.0696 - val_loss: 0.0052 - val_mae: 0.0565
# Epoch 32/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0077 - mae: 0.0691 - val_loss: 0.0059 - val_mae: 0.0605
# Epoch 33/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0077 - mae: 0.0688 - val_loss: 0.0056 - val_mae: 0.0592
# Epoch 34/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0076 - mae: 0.0679 - val_loss: 0.0053 - val_mae: 0.0565
#
# Training Autumn model...
# Epoch 1/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.2917 - mae: 0.4067 - val_loss: 0.0389 - val_mae: 0.1558
# Epoch 2/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0561 - mae: 0.1880 - val_loss: 0.0375 - val_mae: 0.1539
# Epoch 3/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0392 - mae: 0.1552 - val_loss: 0.0328 - val_mae: 0.1463
# Epoch 4/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0330 - mae: 0.1439 - val_loss: 0.0241 - val_mae: 0.1277
# Epoch 5/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0258 - mae: 0.1280 - val_loss: 0.0177 - val_mae: 0.1112
# Epoch 6/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0224 - mae: 0.1194 - val_loss: 0.0177 - val_mae: 0.1118
# Epoch 7/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0212 - mae: 0.1150 - val_loss: 0.0190 - val_mae: 0.1164
# Epoch 8/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0194 - mae: 0.1100 - val_loss: 0.0151 - val_mae: 0.0980
# Epoch 9/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0184 - mae: 0.1080 - val_loss: 0.0102 - val_mae: 0.0817
# Epoch 10/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.
100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0113 - mae: 0.0820 - val_loss: 0.0106 - val_mae: 0.0817
# Epoch 21/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0097 - mae: 0.0768 - val_loss: 0.0080 - val_mae: 0.0689
# Epoch 22/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0107 - mae: 0.0792 - val_loss: 0.0094 - val_mae: 0.0750
# Epoch 23/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0092 - mae: 0.0728 - val_loss: 0.0093 - val_mae: 0.0735
# Epoch 24/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0098 - mae: 0.0754 - val_loss: 0.0106 - val_mae: 0.0772
# Epoch 25/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0104 - mae: 0.0779 - val_loss: 0.0093 - val_mae: 0.0735
# Epoch 26/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0096 - mae: 0.0750 - val_loss: 0.0089 - val_mae: 0.0708
# Epoch 27/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0085 - mae: 0.0697 - val_loss: 0.0064 - val_mae: 0.0598
# Epoch 28/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0087 - mae: 0.0717 - val_loss: 0.0062 - val_mae: 0.0610
# Epoch 29/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0095 - mae: 0.0759 - val_loss: 0.0088 - val_mae: 0.0683
# Epoch 30/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0093 - mae: 0.0743 - val_loss: 0.0061 - val_mae: 0.0606
# Epoch 31/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0078 - mae: 0.0680 - val_loss: 0.0053 - val_mae: 0.0547
# Epoch 32/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0081 - mae: 0.0683 - val_loss: 0.0053 - val_mae: 0.0525
# Epoch 33/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0078 - mae: 0.0679 - val_loss: 0.0049 - val_mae: 0.0509
# Epoch 34/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0075 - mae: 0.0660 - val_loss: 0.0069 - val_mae: 0.0660
# Epoch 35/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0079 - mae: 0.0675 - val_loss: 0.0049 - val_mae: 0.0538
# Epoch 36/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0079 - mae: 0.0688 - val_loss: 0.0053 - val_mae: 0.0564
# Epoch 37/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0070 - mae: 0.0645 - val_loss: 0.0109 - val_mae: 0.0894
# Epoch 38/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0081 - mae: 0.0699 - val_loss: 0.0054 - val_mae: 0.0539
# Epoch 39/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0077 - mae: 0.0665 - val_loss: 0.0058 - val_mae: 0.0595
# Epoch 40/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0073 - mae: 0.0657 - val_loss: 0.0068 - val_mae: 0.0618
# Epoch 41/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0067 - mae: 0.0627 - val_loss: 0.0069 - val_mae: 0.0642
# Epoch 42/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0076 - mae: 0.0673 - val_loss: 0.0052 - val_mae: 0.0536
# Epoch 43/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0066 - mae: 0.0612 - val_loss: 0.0045 - val_mae: 0.0494
# Epoch 44/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0069 - mae: 0.0620 - val_loss: 0.0049 - val_mae: 0.0561
# Epoch 45/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0062 - mae: 0.0596 - val_loss: 0.0053 - val_mae: 0.0563
# Epoch 46/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0060 - mae: 0.0589 - val_loss: 0.0050 - val_mae: 0.0533
# Epoch 47/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0073 - mae: 0.0649 - val_loss: 0.0063 - val_mae: 0.0594
# Epoch 48/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0067 - mae: 0.0634 - val_loss: 0.0062 - val_mae: 0.0632
# Epoch 49/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0066 - mae: 0.0618 - val_loss: 0.0046 - val_mae: 0.0518
# Epoch 50/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0069 - mae: 0.0640 - val_loss: 0.0060 - val_mae: 0.0625
# Epoch 51/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0063 - mae: 0.0612 - val_loss: 0.0045 - val_mae: 0.0519
# Epoch 52/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0062 - mae: 0.0605 - val_loss: 0.0042 - val_mae: 0.0504
# Epoch 53/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0057 - mae: 0.0589 - val_loss: 0.0053 - val_mae: 0.0580
# Epoch 54/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0059 - mae: 0.0594 - val_loss: 0.0038 - val_mae: 0.0460
# Epoch 55/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0060 - mae: 0.0600 - val_loss: 0.0040 - val_mae: 0.0484
# Epoch 56/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0058 - mae: 0.0577 - val_loss: 0.0043 - val_mae: 0.0481
# Epoch 57/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0065 - mae: 0.0614 - val_loss: 0.0047 - val_mae: 0.0508
# Epoch 58/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0055 - mae: 0.0569 - val_loss: 0.0048 - val_mae: 0.0525
# Epoch 59/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0056 - mae: 0.0574 - val_loss: 0.0042 - val_mae: 0.0482
# Epoch 60/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0057 - mae: 0.0575 - val_loss: 0.0058 - val_mae: 0.0547
# Epoch 61/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0063 - mae: 0.0599 - val_loss: 0.0043 - val_mae: 0.0512
# Epoch 62/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0059 - mae: 0.0579 - val_loss: 0.0045 - val_mae: 0.0529
# Epoch 63/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0053 - mae: 0.0544 - val_loss: 0.0042 - val_mae: 0.0510
# Epoch 64/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0051 - mae: 0.0539 - val_loss: 0.0046 - val_mae: 0.0495

# %% [markdown]
# # Cell 8 - Evaluate Models """# Evaluate Models Performance"""

# %%
def evaluate_seasonal_model(model, X, y, scaler, season):
    """Evaluate model performance"""
    y_pred = model.predict(X)
    
    # Inverse transform predictions and actual values
    y_pred = scaler.inverse_transform(y_pred)
    y_actual = scaler.inverse_transform(y.reshape(-1, 1))
    
    # Calculate metrics
    mae = mean_absolute_error(y_actual, y_pred)
    rmse = np.sqrt(mean_squared_error(y_actual, y_pred))
    mape = np.mean(np.abs((y_actual - y_pred) / y_actual)) * 100
    
    print(f"\n{season} Model Performance:")
    print(f"MAE: {mae:.2f}")
    print(f"RMSE: {rmse:.2f}")
    print(f"MAPE: {mape:.2f}%")
    
    return y_pred, y_actual

# Evaluate each model
for season in ['Spring', 'Summer', 'Autumn', 'Winter']:
    _, _, X_val, y_val, _ = prepare_seasonal_data(seasonal_dfs[season])
    y_pred, y_actual = evaluate_seasonal_model(
        models[season], X_val, y_val, scalers[season], season
    )
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step
#
# Spring Model Performance:
# MAE: 0.90
# RMSE: 1.17
# MAPE: inf%
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step
#
# Summer Model Performance:
# MAE: 0.85
# RMSE: 1.09
# MAPE: inf%
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step
#
# Autumn Model Performance:
# MAE: 0.79
# RMSE: 1.06
# MAPE: inf%
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step
#
# Winter Model Performance:
# MAE: 0.95
# RMSE: 1.29
# MAPE: inf%

# %% [markdown]
# # Cell 9 - Generate 2003 Forecasts """# Generate Forecasts for 2003"""

# %%
def generate_season_forecast(model, last_sequence, n_steps, scaler, reset_interval=168):
    """Generate future predictions with periodic reset"""
    predictions = []
    current_sequence = last_sequence.copy()
    
    for i in range(n_steps):
        # Reset sequence periodically to avoid error accumulation
        if i % reset_interval == 0 and i > 0:
            current_sequence = np.roll(last_sequence, -reset_interval)
            current_sequence[-reset_interval:] = np.array(predictions[-reset_interval:])
        
        next_pred = model.predict(current_sequence.reshape(1, 24, 1))
        predictions.append(next_pred[0, 0])
        
        current_sequence = np.roll(current_sequence, -1)
        current_sequence[-1] = next_pred
    
    predictions = np.array(predictions).reshape(-1, 1)
    return scaler.inverse_transform(predictions)

# %%
# Generate 2003 forecasts for each season
forecasts_2003 = {}
for season in ['Spring', 'Summer', 'Autumn', 'Winter']:
    # Get last sequence from 2002
    _, _, X_val, _, _ = prepare_seasonal_data(seasonal_dfs[season])
    last_sequence = X_val[-1]
    
    # Generate forecasts (approximately 4 days = 96 hours)
    forecasts_2003[season] = generate_season_forecast(
        models[season], last_sequence, 96, scalers[season]
    )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %% [markdown]
# # Cell 10 - Visualize Results """# Visualize Results"""

# %%
# Print summary statistics for 2003 forecasts
print("\nForecast Statistics for 2003:")
for season in ['Spring', 'Summer', 'Autumn', 'Winter']:
    print(f"\n{season}:")
    print(f"Mean: {forecasts_2003[season].mean():.2f} m/s")
    print(f"Max: {forecasts_2003[season].max():.2f} m/s")
    print(f"Min: {forecasts_2003[season].min():.2f} m/s")
# Out:
# Forecast Statistics for 2003:
#
# Spring:
# Mean: 2.21 m/s
# Max: 6.64 m/s
# Min: 1.66 m/s
#
# Summer:
# Mean: 1.99 m/s
# Max: 2.07 m/s
# Min: 1.82 m/s
#
# Autumn:
# Mean: 1.51 m/s
# Max: 2.88 m/s
# Min: 1.27 m/s
#
# Winter:
# Mean: 6.94 m/s
# Max: 8.82 m/s
# Min: 6.67 m/s

# %%
"""# Comprehensive Seasonal Visualizations"""

# Set style for better visualizations
plt.style.use('bmh')  # Using 'bmh' style instead of seaborn
colors = {
    'historical': '#2ecc71',  # green
    'test': '#3498db',       # blue
    'forecast': '#e74c3c',   # red
    'predicted': '#9b59b6'   # purple
}

# Create visualization for each season
for season in ['Spring', 'Summer', 'Autumn', 'Winter']:
    plt.figure(figsize=(15, 8))
    
    # Plot historical data (2001)
    historical_data = seasonal_dfs[season][seasonal_dfs[season].index.year == 2001]['Wind (m/s 10 m)']
    plt.plot(range(len(historical_data)), 
            historical_data, 
            label='Historical (2001)', 
            color=colors['historical'], 
            alpha=0.7)
    
    # Plot test data (2002)
    test_data = seasonal_dfs[season][seasonal_dfs[season].index.year == 2002]['Wind (m/s 10 m)']
    plt.plot(range(len(historical_data), len(historical_data) + len(test_data)), 
            test_data, 
            label='Actual (2002)', 
            color=colors['test'], 
            alpha=0.7)
    
    # Plot test predictions
    _, _, X_val, y_val, _ = prepare_seasonal_data(seasonal_dfs[season])
    test_pred = models[season].predict(X_val)
    test_pred = scalers[season].inverse_transform(test_pred)
    plt.plot(range(len(historical_data) + 24, len(historical_data) + len(test_data)), 
            test_pred, 
            label='Predicted (2002)', 
            color=colors['predicted'], 
            linestyle='--', 
            alpha=0.7)
    
    # Plot 2003 forecasts
    forecast = forecasts_2003[season]
    plt.plot(range(len(historical_data) + len(test_data), 
                  len(historical_data) + len(test_data) + len(forecast)), 
            forecast, 
            label='Forecast (2003)', 
            color=colors['forecast'], 
            linestyle='--', 
            alpha=0.7)
    
    # Customize plot
    plt.title(f'{season} Wind Speed: Historical, Test, and Forecast', fontsize=14, pad=20)
    plt.xlabel('Time Steps (Hours)', fontsize=12)
    plt.ylabel('Wind Speed (m/s)', fontsize=12)
    plt.legend(fontsize=10, loc='upper right')
    plt.grid(True, alpha=0.3)
    
    # Add vertical lines to separate years
    plt.axvline(x=len(historical_data), color='gray', linestyle='--', alpha=0.5)
    plt.axvline(x=len(historical_data) + len(test_data), color='gray', linestyle='--', alpha=0.5)
    
    # Add year labels
    plt.text(len(historical_data)/2, plt.ylim()[1], '2001', 
             horizontalalignment='center', verticalalignment='bottom')
    plt.text(len(historical_data) + len(test_data)/2, plt.ylim()[1], '2002', 
             horizontalalignment='center', verticalalignment='bottom')
    plt.text(len(historical_data) + len(test_data) + len(forecast)/2, plt.ylim()[1], '2003', 
             horizontalalignment='center', verticalalignment='bottom')
    
    plt.tight_layout()
    plt.show()
    
    # Print performance metrics for each period
    print(f"\n{season} Performance Metrics:")
    print("=" * 50)
    
    # Test set (2002) metrics
    test_mae = mean_absolute_error(test_data[24:], test_pred)
    test_rmse = np.sqrt(mean_squared_error(test_data[24:], test_pred))
    test_mape = np.mean(np.abs((test_data[24:] - test_pred.flatten()) / test_data[24:])) * 100
    
    print(f"2002 Test Set Metrics:")
    print(f"MAE: {test_mae:.2f}")
    print(f"RMSE: {test_rmse:.2f}")
    print(f"MAPE: {test_mape:.2f}%")
    
    # Basic statistics
    print(f"\nWind Speed Statistics:")
    print(f"2001 Mean: {historical_data.mean():.2f} m/s")
    print(f"2002 Mean: {test_data.mean():.2f} m/s")
    print(f"2003 Forecast Mean: {forecast.mean():.2f} m/s")
    print("=" * 50)
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Spring Performance Metrics:
# ==================================================
# 2002 Test Set Metrics:
# MAE: 0.90
# RMSE: 1.17
# MAPE: inf%
#
# Wind Speed Statistics:
# 2001 Mean: 5.23 m/s
# 2002 Mean: 5.35 m/s
# 2003 Forecast Mean: 2.21 m/s
# ==================================================
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Summer Performance Metrics:
# ==================================================
# 2002 Test Set Metrics:
# MAE: 0.85
# RMSE: 1.09
# MAPE: inf%
#
# Wind Speed Statistics:
# 2001 Mean: 6.53 m/s
# 2002 Mean: 6.23 m/s
# 2003 Forecast Mean: 1.99 m/s
# ==================================================
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Autumn Performance Metrics:
# ==================================================
# 2002 Test Set Metrics:
# MAE: 0.79
# RMSE: 1.06
# MAPE: inf%
#
# Wind Speed Statistics:
# 2001 Mean: 5.70 m/s
# 2002 Mean: 4.39 m/s
# 2003 Forecast Mean: 1.51 m/s
# ==================================================
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Winter Performance Metrics:
# ==================================================
# 2002 Test Set Metrics:
# MAE: 0.95
# RMSE: 1.29
# MAPE: inf%
#
# Wind Speed Statistics:
# 2001 Mean: 5.03 m/s
# 2002 Mean: 5.09 m/s
# 2003 Forecast Mean: 6.94 m/s
# ==================================================
